# %%
# import the packages
# read the data
# divide the into cat num columns

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path="Visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# ## prevailing_wage

# %% [markdown]
# - len
# - max
# - min
# - mean
# - median
# - 25 percentile
# - 50 percentile
# - 75 percentile

# %%
wage_data=visa_df['prevailing_wage']
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
len(wage_data)
# Out:
# 25480

# %%
min(wage_data)
# Out:
# 2.1367

# %%
wage_data.min()
# Out:
# 2.1367

# %%
np.min(wage_data)
# Out:
# 2.1367

# %%
wage_data=visa_df['prevailing_wage']
min(wage_data),wage_data.min(),np.min(wage_data)
# Out:
# (2.1367, 2.1367, 2.1367)

# %%
wage_data=visa_df['prevailing_wage']
max(wage_data),wage_data.max(),np.max(wage_data)
# Out:
# (319210.27, 319210.27, 319210.27)

# %%
wage_data.mean(),np.mean(wage_data)
# Out:
# (np.float64(74455.81459209183), np.float64(74455.81459209183))

# %%
wage_data.median(),np.median(wage_data)
# Out:
# (70308.20999999999, np.float64(70308.20999999999))

# %% [markdown]
# ## quantile-percentile

# %%
p_25=np.percentile(wage_data,25)
print(p_25)
# Out:
# 34015.479999999996

# %%
p_50=np.percentile(wage_data,50)
print(p_50)
# Out:
# 70308.20999999999

# %%
p_75=np.percentile(wage_data,75)
print(p_75)
# Out:
# 107735.51250000001

# %%
q_25=np.quantile(wage_data,0.25)
q_50=np.quantile(wage_data,0.50)
q_75=np.quantile(wage_data,0.75)
print(q_25)
print(q_50)
print(q_75)
# Out:
# 34015.479999999996
# 70308.20999999999
# 107735.51250000001

# %%
np.quantile(wage_data,25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 np.quantile(wage_data,25)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:4491, in quantile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4488     q = np.asanyarray(q)
#    4490 if not _quantile_is_valid(q):
# -> 4491     raise ValueError("Quantiles must be in the range [0, 1]")
#    4493 if weights is not None:
#    4494     if method != "inverted_cdf":
#
# ValueError: Quantiles must be in the range [0, 1]

# %%
np.quantile(wage_data,0.25)
# Out:
# np.float64(34015.479999999996)

# %%
wage_data=visa_df['prevailing_wage']  # i
wage_count=len(wage_data)
wage_min=round(wage_data.min(),2)
wage_mean=round(wage_data.mean(),2)
wage_med=round(wage_data.median(),2)
wage_25p=round(np.percentile(wage_data,25))
wage_50p=round(np.percentile(wage_data,50))
wage_75p=round(np.percentile(wage_data,75))
wage_max=round(wage_data.max(),2)
l=[wage_count,wage_min,wage_mean,wage_med,wage_25p,wage_50p,wage_75p,wage_max]
ID=['Count','Min','Mean','Median','25p','50p','75p','Max']
# df=pd.DataFrame(l,columns=['prevailing_wage'],index=ID)
pd.DataFrame(l,ID,['prevailing_wage'])
# Out:
#         prevailing_wage
# Count          25480.00
# Min                2.14
# Mean           74455.81
# Median         70308.21
# 25p            34015.00
# 50p            70308.00
# 75p           107736.00
# Max           319210.27

# %%
L=[]
for i in num:
    data=visa_df[i]
    count=len(data)
    Min=round(data.min(),2)
    mean=round(data.mean(),2)
    med=round(data.median(),2)
    p_25=round(np.percentile(data,25))
    p_50=round(np.percentile(data,50))
    p_75=round(np.percentile(data,75))
    Max=round(data.max(),2)
    l=[count,Min,mean,med,p_25,p_50,p_75,Max]
    L.append(l)
    ID=['Count','Min','Mean','Median','25p','50p','75p','Max']

pd.DataFrame(L,columns=ID,index=num).T
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# Count          25480.00     25480.00         25480.00
# Min              -26.00      1800.00             2.14
# Mean            5667.04      1979.41         74455.81
# Median          2109.00      1997.00         70308.21
# 25p             1022.00      1976.00         34015.00
# 50p             2109.00      1997.00         70308.00
# 75p             3504.00      2005.00        107736.00
# Max           602069.00      2016.00        319210.27

# %%
visa_df.describe()   # describe_function
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# ## pecentile concept
#
# - 25p: 25 percentage of data below 25p value
# - wage_25p : 34015.48
#     - there 25*(25480)/100=6370 applicants have salary less than 34015
#
# - wage_50p: 70308.12
#      - there 50*(25480)/100=12740 applicants have salary less than 70308.12
#
# - wage_75p:107735.51
#     - there 75*(25480)/100=19110 applicants have salary less than 107735.51

# %%
con=visa_df['prevailing_wage']<wage_25p
# len(visa_df[con]),len(visa_df)*25/100
len(visa_df[con])==len(visa_df)*25/100
# Out:
# True

# %%
con=visa_df['prevailing_wage']<wage_50p
len(visa_df[con])==len(visa_df)*50/100
# Out:
# True

# %%
con=visa_df['prevailing_wage']<wage_75p
len(visa_df[con])==len(visa_df)*75/100
# Out:
# True

# %%
len(visa_df)*25/100
# Out:
# 6370.0

# %%
len(visa_df)*50/100
# Out:
# 12740.0

# %%
len(visa_df)*75/100
# Out:
# 19110.0

# %%
## Emperical Rule

u-1*sigma  to u+1*sigma   68%

step-1: wage data mean (u)
step-2: wage data std(sigma)
step-3: LB=u-1*sigma
step-4: UB=u+1*sigma
step-5: con1=visa_df['prevailing_wage']>LB
step-6: con2=visa_df['prevailing_wage']<UB
step-7:con=con1 & con2
step-8:len(visa_df[con])
# Out:
#   Cell In[29], line 3
#     u-1*sigma  to u+1*sigma   68%
#                ^
# SyntaxError: invalid syntax

# %%
wage_data=visa_df['prevailing_wage']
U=wage_data.mean()
sigma=wage_data.std()
LB=U-1*sigma
UB=U+1*sigma
con1=visa_df['prevailing_wage']>LB
con2=visa_df['prevailing_wage']<UB
con=con1 & con2
len(visa_df[con])==68*25480/100
# Out:
# False

# %% [markdown]
# ## Conclusion: Empirical rule failed wage data does not following normal distribution

# %% [markdown]
# ## Histogram

# %%
plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(wage_data,bins=40)
# Out:
# (array([2992.,  871., 1005., 1170., 1242., 1434., 1385., 1443., 1444.,
#         1445., 1457., 1335., 1268., 1217., 1088.,  978.,  807.,  645.,
#          509.,  373.,  264.,  144.,  105.,  111.,  107.,   99.,   88.,
#           79.,   65.,   64.,   58.,   53.,   33.,   33.,   29.,   19.,
#            7.,    3.,    6.,    5.]),
#  array([2.13670000e+00, 7.98234003e+03, 1.59625434e+04, 2.39427467e+04,
#         3.19229500e+04, 3.99031534e+04, 4.78833567e+04, 5.58635600e+04,
#         6.38437634e+04, 7.18239667e+04, 7.98041700e+04, 8.77843734e+04,
#         9.57645767e+04, 1.03744780e+05, 1.11724983e+05, 1.19705187e+05,
#         1.27685390e+05, 1.35665593e+05, 1.43645797e+05, 1.51626000e+05,
#         1.59606203e+05, 1.67586407e+05, 1.75566610e+05, 1.83546813e+05,
#         1.91527017e+05, 1.99507220e+05, 2.07487423e+05, 2.15467627e+05,
#         2.23447830e+05, 2.31428033e+05, 2.39408237e+05, 2.47388440e+05,
#         2.55368643e+05, 2.63348847e+05, 2.71329050e+05, 2.79309253e+05,
#         2.87289457e+05, 2.95269660e+05, 3.03249863e+05, 3.11230067e+05,
#         3.19210270e+05]),
#  <BarContainer object of 40 artists>)

# %%
inter_count,inter_vals,n=plt.hist(wage_data,bins=10)

# %%
inter_count
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
inter_vals
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
wage_data=visa_df['prevailing_wage']
lb=2.13670000e+00
ub=3.19229500e+04
con1=wage_data>=lb
con2=wage_data<ub
con=con1 & con2
len(visa_df[con])
# Out:
# 6038

# %% [markdown]
# ## Outlier Analysis

# %% [markdown]
# - we understand emperical rule failed
# - then we plotted histogram its slightly deviated
# - So iot indicates the data has outliers
# - Ouliers can be show by Box plot
#
#
#            Q1-1.5IQR   Q1   median  Q3   Q3+1.5IQR
#                        |-----:-----|
#        o      |--------|     :     |--------|    o  o
#                        |-----:-----|
#      flier             <----------->            fliers
#                             IQR

# %% [markdown]
# ### boxplot

# %%
wage_data=visa_df['prevailing_wage']
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
plt.subplot(1,2,1)
# Out:
# <Axes: >

# %%
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,4))
plt.subplot(1,2,1).hist(wage_data)
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.show()

# %% [markdown]
# ## Outliers data

# %%
# q1
# q2
# q3
# IQR=q3-q1
# UB=q3+1.5*IQR
# LB=q3-1.5*IQR
# con1= wage > UB
# con2= wage < LB
# con= con1 / con2 outliers

# con1= wage<UB
# con2=wage > LB
# con= con1 & con2

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(data,25)
q2=np.percentile(data,50)
q3=np.percentile(data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1= wage_data>UB
con2= wage_data<LB
con= con1 | con2
outliers_df=visa_df[con]
len(outliers_df)
# Out:
# 427

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(data,25)
q2=np.percentile(data,50)
q3=np.percentile(data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
con1= wage_data<UB
con2= wage_data>LB
con= con1 & con2
outliers_df=visa_df[con]
len(outliers_df)
# Out:
# 25053

# %%
25053+427==25480
# Out:
# True

# %% [markdown]
# ## Fill the outliers
#
# - drop the outliers
# - fill with median
# - winsorization: fill with LB and UB

# %%
con1= wage_data>UB
con2= wage_data<LB
con= con1 | con2
# we will iterate each value from wage data
# if the value matches:

# %%
outliers_df
outliers_df=visa_df['prevailing_wage']
outliers_df=visa_df['prevailing_wage'].values
outliers=visa_df['prevailing_wage'].values.tolist()
l=[]
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
for value in wage_data:
    if value in outliers:
        l.append(wage_med)
    else:
        l.append(value)
        
visa_df['prevailing_wage1']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  prevailing_wage1
# 0          Denied          70308.21
# 1       Certified          70308.21
# 2          Denied          70308.21
# 3          Denied          70308.21
# 4       Certified          70308.21
# ...           ...               ...
# 25475   Certified          70308.21
# 25476   Certified          70308.21
# 25477   Certified          70308.21
# 25478   Certified          70308.21
# 25479   Certified          70308.21
#
# [25480 rows x 13 columns]

# %%
visa_df['prevailing_wage1']=1
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  prevailing_wage1
# 0          Denied                 1
# 1       Certified                 1
# 2          Denied                 1
# 3          Denied                 1
# 4       Certified                 1
# ...           ...               ...
# 25475   Certified                 1
# 25476   Certified                 1
# 25477   Certified                 1
# 25478   Certified                 1
# 25479   Certified                 1
#
# [25480 rows x 13 columns]

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage1'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage1'],vert=False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.show()

# %%
wage_data=visa_df['prevailing_wage']
q1=np.percentile(data,25)
q2=np.percentile(data,50)
q3=np.percentile(data,75)
IQR=q3-q1
UB=q3+1.5*IQR
LB=q1-1.5*IQR
visa_df['prevailing_wage2']=wage_data.clip(lower=LB,upper=UB)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status  prevailing_wage1  prevailing_wage2
# 0          Denied                 1         592.20290
# 1       Certified                 1       83425.65000
# 2          Denied                 1      122996.86000
# 3          Denied                 1       83434.03000
# 4       Certified                 1      149907.39000
# ...           ...               ...               ...
# 25475   Certified                 1       77092.57000
# 25476   Certified                 1      218315.56125
# 25477   Certified                 1      146298.85000
# 25478   Certified                 1       86154.77000
# 25479   Certified                 1       70876.91000
#
# [25480 rows x 14 columns]

# %%
plt.figure(figsize=(8,4))
plt.subplot(2,2,1).hist(visa_df['prevailing_wage2'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage2'],vert=False)
plt.subplot(2,2,3).hist(wage_data)
plt.subplot(2,2,4).boxplot(wage_data,vert=False)
plt.show()

# %%
outliers_df
outliers_df=visa_df['prevailing_wage']
outliers_df=visa_df['prevailing_wage'].values
outliers=visa_df['prevailing_wage'].values.tolist()
l=[]
wage_data=visa_df['prevailing_wage']
wage_med=wage_data.median()
for value in wage_data:
    if value in outliers_2:
        l.append(wage_med)
    else:
        l.append(value)

visa_df['prevailing_wage']=l
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         70308.21         Hour                  Y
# 1                Northeast         70308.21         Year                  Y
# 2                     West         70308.21         Year                  Y
# 3                     West         70308.21         Year                  Y
# 4                    South         70308.21         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South         70308.21         Year                  Y
# 25476            Northeast         70308.21         Year                  Y
# 25477                South         70308.21         Year                  N
# 25478                 West         70308.21         Year                  Y
# 25479              Midwest         70308.21         Year                  Y
#
#       case_status  prevailing_wage1  prevailing_wage2
# 0          Denied                 1         592.20290
# 1       Certified                 1       83425.65000
# 2          Denied                 1      122996.86000
# 3          Denied                 1       83434.03000
# 4       Certified                 1      149907.39000
# ...           ...               ...               ...
# 25475   Certified                 1       77092.57000
# 25476   Certified                 1      218315.56125
# 25477   Certified                 1      146298.85000
# 25478   Certified                 1       86154.77000
# 25479   Certified                 1       70876.91000
#
# [25480 rows x 14 columns]
