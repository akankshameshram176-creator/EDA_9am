# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suresh','Satish',np.nan],
     'Age':[np.nan,22,25,27],
     'City':['Pune','Pune',np.nan,'Hyd']}

df=pd.DataFrame(Data)
df
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   NaN
# 3     NaN  27.0   Hyd

# %%
df.to_csv('data_missing.csv',index=False)

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %%
df1.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1.dtypes
#
# NameError: name 'df1' is not defined

# %%
df.isnull()

# %%
df.isnull().sum()
# Out:
# Names    1
# Age      1
# City     1
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1.isnull().sum()
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ## fillna

# %%
df.fillna(30)  # Not recomended
# Out:
#     Names   Age  City
# 0  Ramesh  30.0  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0    30
# 3      30  27.0   Hyd

# %%
df1.fillna(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df1.fillna(30)
#
# NameError: name 'df1' is not defined

# %% [markdown]
# - the above one is we are filling randomly
# - all the columns are filled with random number
# - it is not a good approach because in a data we have different data types

# %%
df['Age'].fillna(30)
# Out:
# 0    30.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %%
df.fillna('Hyd')
# Out:
#     Names   Age  City
# 0  Ramesh   Hyd  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     Hyd  27.0   Hyd

# %% [markdown]
# ## What is the difference between np.nan and None

# %%
np.nan+5
# Out:
# nan

# %%
None+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 None+5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1=np.array[1,2,np.nan,3]
arr2=np.array[1,2,None,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 arr1=np.array[1,2,np.nan,3]
#       2 arr2=np.array[1,2,None,3]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
arr1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 arr1
#
# NameError: name 'arr1' is not defined

# %%
arr2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 arr2
#
# NameError: name 'arr2' is not defined

# %%
np.nansum(arr1),np.sum(arr1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 np.nansum(arr1),np.sum(arr1)
#
# NameError: name 'arr1' is not defined

# %%
np.sum(arr2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 np.sum(arr2)
#
# NameError: name 'arr2' is not defined

# %% [markdown]
# - np.nan represents float type
# - None represents Object type
# - if data operations related to Maths then nan format is better

# %% [markdown]
# ## Fill the value based on column

# %%
# df.fillna()
df['Names'].fillna('Manish')
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Satish
# 3    Manish
# Name: Names, dtype: object

# %% [markdown]
# ## Fill with Methods
#
# - whenever we are using methods no need to provide values

# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suresh','Satish',np.nan],
     'Age':[np.nan,22,25,27],
     'City':['Pune','Pune',np.nan,'Hyd']}

df=pd.DataFrame(Data)
df
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   NaN
# 3     NaN  27.0   Hyd

# %% [markdown]
# - pad
# - bfill
# - ffill
# - backfill

# %%
df.fillna(method='pad')
# Out:
# C:\Users\Akanksha\AppData\Local\Temp\ipykernel_17032\196241153.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0  Pune
# 3  Satish  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad')
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0  Pune
# 3  Satish  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='bfill')
# Out:
#     Names   Age  City
# 0  Ramesh  22.0  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     NaN  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='ffill')
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0  Pune
# 3  Satish  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='backfill')
# Out:
#     Names   Age  City
# 0  Ramesh  22.0  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     NaN  27.0   Hyd

# %% [markdown]
# ## Mean-Median-Mode
# - instead of fillng with random values
# - we can use mean median and mode also
# - For Numerical columns use mean and Median
#   - if data

# %%
age_median=df['Age'].median()
df['Age'].fillna(age_median)
# Out:
# 0    25.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %%
age_median
# Out:
# 25.0

# %%
mode=df['City'].mode()
mode
# Out:
# 0    Pune
# Name: City, dtype: object

# %% [markdown]
# ## KNN Immputer
#
# - K- Nearest Neighbours
# - Where k= hyper parameter which means the user can change
# - Idea: Instead of taking all the samples average
#     - First fix the neighbours number i.e.k
#     - Then find the neighbours using distance metric
#     - Then take the avarage of those samples to fill the missing value
#
# digram and formula of hypotenus

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
pd.DataFrame(X)
# Out:
#      0     1    2
# 0  1.0   2.0  NaN
# 1  3.0   NaN  3.0
# 2  NaN  60.0  5.0
# 3  8.0   8.0  7.0

# %%
# Import method
# save method
# apply fit transform

# %%
import numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],
   [np.nan,60,5],[8,8,7]]
imputer = KNNImputer(n_neighbors=2,
                    weights='uniform')
imputer.fit_transform(X)
# Out:
# array([[ 1. ,  2. ,  5. ],
#        [ 3. , 31. ,  3. ],
#        [ 5.5, 60. ,  5. ],
#        [ 8. ,  8. ,  7. ]])

# %%
import numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],
   [np.nan,60,5],[8,8,7]]
imputer = KNNImputer(n_neighbors=2,
                    weights='distance')
imputer.fit_transform(X)
# Out:
# array([[ 1.        ,  2.        ,  3.93905505],
#        [ 3.        , 31.        ,  3.        ],
#        [ 3.25775362, 60.        ,  5.        ],
#        [ 8.        ,  8.        ,  7.        ]])
