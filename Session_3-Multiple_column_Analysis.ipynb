# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path="Visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# ### frequency table

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
               columns=['Label','No of applicants'])
df.to_csv('continent.csv',index=False)

# %% [markdown]
# ### idea
# - I want to create all frequency tables
# - and save in a new folder
# - The folder is available in python current file location
# - All steps automate

# %% [markdown]
# ### step-1: create a folder using python code

# %%
import os
try:
    os.makedirs('frequency_table')
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'frequency_table'

# %%
os.makedirs('frequency_table1',exist_ok=True)

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
               columns=['Label','No of applicants'])

# Absolute path
path=r'C:\Users\Akanksha\Documents\Naresh IT\EDA\frequency_table\continent.csv'
df.to_csv(path,index=False)

# %%
# Relative path

path=r'.\frequency_table\continent1.csv'
df.to_csv(path,index=False)

# %%
cwd=os.getcwd()  #EDA
folder_name='frequency_table'
new_dir=os.path.join(cwd,folder_name)
filename='continent2.csv'
path=os.path.join(new_dir,filename)
df.to_csv(path,index=False)

# %%
cat
cat[1:]
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['case_id'].nunique()
# Out:
# 25480

# %%
# step-1:  
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
               columns=['Label','No of applicants'])

# step-2:
folder_name='frequency_table'
os.makedirs(folder_name,exist_ok=True)

# step-3:
cwd=os.getcwd()
new_dir=os.path.join(cwd,folder_name)
file_name='continent.csv'
path=os.path.join(new_dir,file_name)

# step-4:
df.to_csv(path,index=False)

# %%
# step-1:  
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    df=pd.DataFrame(zip(keys,values),
                   columns=['Label','No of applicants'])
    
    # step-2:
    folder_name='frequency_table'
    os.makedirs(folder_name,exist_ok=True)
    
    # step-3:
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path=os.path.join(new_dir,file_name)
    
    # step-4:
    df.to_csv(path,index=False)

# %% [markdown]
# ## bar chart automate

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df ['continent'].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys, values)
plt.xlabel('labels')
plt.ylabel('count')
plt.title('continet_barchart')
plt.savefig('Continent_bar.jpg')

# %%
# step-1:  
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    df=pd.DataFrame(zip(keys,values),
                   columns=['Label','No of applicants'])
    
    # step-2:
    folder_name='bar_table'
    os.makedirs(folder_name,exist_ok=True)
    
    # step-3:
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path=os.path.join(new_dir,file_name)
    
    # step-4:
    df.to_csv(path,index=False)

# %%
# step-1:  
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    df=pd.DataFrame(zip(keys,values),
                   columns=['Label','No of applicants'])
    
    # step-2:
    folder_name='Pie_charts'
    os.makedirs(folder_name,exist_ok=True)
    
    # step-3:
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path=os.path.join(new_dir,file_name)
    
    # step-4:
    df.to_csv(path,index=False)

# %%
# step-1:
for i in cat[1:]: # misrake cat:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,3))
    plt.bar(keys,values)
    # step-2
    folder_name='Bar_charts'
    os.makedirs(folder_name,exist_ok=True)
    # step-3:
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path=os.path.join(new_dir,file_name)
    # step-4:
    plt.savefig(path)

# %%
# step-1:  
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.pie(values,explode=[0.1 for i in range(len(keys))])
    
    # step-2:
    folder_name='Pie_charts'
    os.makedirs(folder_name,exist_ok=True)
    
    # step-3:
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path=os.path.join(new_dir,file_name)
    
    # step-4:
    plt.savefig(path)

# %%
# import the packages
# read the data
# divide into categorical and num column

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path="Visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
# bar chart for continent

keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.show()

# %% [markdown]
# ### subplots
#
# - multiplots we can plot in single area

# %%
plt.subplot(2,2,1)
plt.title('2-2-1')
plt.subplot(2,2,2)
plt.title('2-2-2')
plt.subplot(2,2,3)
plt.title('2-2-3')
plt.subplot(2,2,4)
plt.title('2-2-4')
# Out:
# Text(0.5, 1.0, '2-2-4')

# %%
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
plt.subplot(3,1,1)
plt.subplot(3,1,2)
plt.subplot(3,1,3)
# Out:
# <Axes: >

# %%
# I want to draw total 9 cate column are there
# In that we should not consider case id
# so remaining * column so we need 8 plots
# (1,8) or (8,1) or (2,4) or (4,2) or (3,3)

# plt.subplot(2,2,1)
# plt.subplot(2,2,2)
# plt.subplot(2,2,3)
# plt.subplot(2,2,4)
# we do not write the 4 lines

# plt.subplot(2,2,i)
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
# I want 9 plots
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
# bar chart for continent
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)
    plt.show()

# %%
plt.figure(figsize=(28,10))
for i in range(1,len(cat)):                  # cat[0] caseid we are not using cta[1]
   # print(i,cat[i])
    keys=visa_df[cat[i]].value_counts().keys()  # i = column name
    values=visa_df[cat[i]].value_counts().values  # i = column name
    plt.subplot(3,3,i).bar(keys,values)   # i = number
    plt.title(f'{cat[i]}_bar_chart')
    plt.suptitle('Barchart')
