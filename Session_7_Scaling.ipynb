# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path="Visadataset.csv"
visa_df=pd.read_csv(path)
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# - we have two types of scaling
#     - Z score(Standardization)
#     - MIn max scalar (Normalization)

# %% [raw]
# Z score

# %%
# step-1: read pwage column  x
# step-2: calculate mean pwage
# step-3: calculate std of wage
# step-4: pwage-mean
# step-5: visa_df[p_z]  step4/step3

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=wage_data.mean()
wage_std=wage_data.std()
visa_df['prevailing_wage_z'] = (wage_data - wage_mean)/wage_std

# %%
visa_df[['prevailing_wage','prevailing_wage_z']]
# Out:
#        prevailing_wage  prevailing_wage_z
# 0             592.2029          -1.398510
# 1           83425.6500           0.169832
# 2          122996.8600           0.919060
# 3           83434.0300           0.169991
# 4          149907.3900           1.428576
# ...                ...                ...
# 25475       77092.5700           0.049923
# 25476      279174.7900           3.876083
# 25477      146298.8500           1.360253
# 25478       86154.7700           0.221504
# 25479       70876.9100          -0.067762
#
# [25480 rows x 2 columns]

# %%
plt.subplot(2,2,1).hist(visa_df['prevailing_wage'])
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage'],vert=False)
plt.subplot(2,2,3).hist(visa_df['prevailing_wage'])
plt.subplot(2,2,4).boxplot(visa_df['prevailing_wage'],vert=False)
plt.show()

# %% [markdown]
# - sklearn
#     - preprocessing
#         - standardScalar
# - import the package
# - save the package
# - apply fit transform

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
visa_df['prevailing_wage_ss']=ss.fit_transform(visa_df[['prevailing_wage']])

# %%
visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_ss']]
# Out:
#        prevailing_wage  prevailing_wage_z  prevailing_wage_ss
# 0             592.2029          -1.398510           -1.398537
# 1           83425.6500           0.169832            0.169835
# 2          122996.8600           0.919060            0.919079
# 3           83434.0300           0.169991            0.169994
# 4          149907.3900           1.428576            1.428604
# ...                ...                ...                 ...
# 25475       77092.5700           0.049923            0.049924
# 25476      279174.7900           3.876083            3.876159
# 25477      146298.8500           1.360253            1.360280
# 25478       86154.7700           0.221504            0.221509
# 25479       70876.9100          -0.067762           -0.067763
#
# [25480 rows x 3 columns]

# %% [markdown]
# ## Normalization

# %%
Do based on formula
Method name : MinMaxScaler
Compare both answers

# Read the data again
# step-1: read pwage column x
# step-2: calculate mean pwage
# step-3: calculate std of wage
# step-4: pwage-mean
# step-5: visa_df[p_z]  step4/step3

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=wage_data.mean()
wage_std=wage_data.std()
visa_df['prevailing_wage_z'] = (wage_data - wage_mean)/wage_std

# %%
visa_df[['prevailing_wage','prevailing_wage_z']]

# %%
from sklearn.preprocessing import minmax_scale
mmS = minmax_scale(visa_df['prevailing_wage'])
visa_df['prevailing_wage_mmS'] = mmS

# %%
visa_df[['prevailing_wage','prevailing_wage_z','prevailing_wage_mmS']]
# Out:
#        prevailing_wage  prevailing_wage_z  prevailing_wage_mmS
# 0             592.2029          -1.398510             0.001849
# 1           83425.6500           0.169832             0.261345
# 2          122996.8600           0.919060             0.385312
# 3           83434.0300           0.169991             0.261371
# 4          149907.3900           1.428576             0.469616
# ...                ...                ...                  ...
# 25475       77092.5700           0.049923             0.241505
# 25476      279174.7900           3.876083             0.874579
# 25477      146298.8500           1.360253             0.458311
# 25478       86154.7700           0.221504             0.269895
# 25479       70876.9100          -0.067762             0.222033
#
# [25480 rows x 3 columns]

# %%
plt.subplot(2,2,1).hist(wageData)
plt.subplot(2,2,2).boxplot(wageData,vert=False)
plt.subplot(2,2,3).hist(visa_df['prevailing_wage_mmS'])
plt.subplot(2,2,4).boxplot(visa_df['prevailing_wage_mmS'],vert=False)
plt.show()
